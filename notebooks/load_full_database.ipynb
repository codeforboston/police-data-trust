# %%
import os
import math
import pandas as pd
import requests
from dateutil import parser

# %%
import sys
sys.path.append("..")

from backend.api import create_app, db
from backend.database import UseOfForce, Incident, Officer

app = create_app("development")

# %%
isnan = lambda x: isinstance(x, float) and math.isnan(x)
nan_to_none = lambda x: None if isnan(x) else x
parse_date = lambda s: parser.parse(s) if isinstance(s, str) else None

# %%
# Load the full database produced by flask scrape and cache the dataframe for faster loads

scraper_output = '../excel_outputs'
pkl_cache = os.path.join(scraper_output, 'full_database.pkl.zip')
spreadsheet = os.path.join(scraper_output,'full_database.xlsx')

if os.path.exists(pkl_cache):
    data = pd.read_pickle(pkl_cache)
else:
    excel_sheets = pd.read_excel(spreadsheet, sheet_name=None)
    data = pd.concat(excel_sheets.values(), axis=1)
    data.to_pickle(pkl_cache)

# %%
data.iloc[2]
# Out:
# columns Index(['Unnamed: 0', 'record_type', 'attachments_available', 'record_id',
#        'data_source_id', 'Unnamed: 0', 'description', 'death_location_city',
#        'death_location_county', 'death_location_state',
#        'death_location_street_address', 'department_present', 'perpetrator',
#        'incident_date', 'incident_time', 'record_id', 'Unnamed: 0',
#        'victim_age', 'victim_name_full', 'victim_race', 'victim_sex',
#        'Unnamed: 0', 'death_manner'],
#       dtype='object')
# Unnamed: 0                                                                      22
# record_type                                                           news article
# attachments_available                                                          NaN
# record_id                                                                      NaN
# data_source_id                                                                 mpv
# Unnamed: 0                                                                      22
# description                      Police responded to reports of a disturbance a...
# death_location_city                                                     Huntsville
# death_location_county                                                       Walker
# death_location_state                                                            TX
# death_location_street_address                                         5300 FM 1374
# department_present                                  Walker County Sheriff's Office
# perpetrator                                                                    NaN
# incident_date                                                  2021-09-16 00:00:00
# incident_time                                                                  NaN
# record_id                                                                      NaN
# Unnamed: 0                                                                      22
# victim_age                                                                 Unknown
# victim_name_full                                           Name withheld by police
# victim_race                                                           Unknown race
# victim_sex                                                                    Male
# Unnamed: 0                                                                      22
# death_manner                                                               Gunshot
# Name: 2, dtype: object

# %%
def orm_location(row):
    fields = list(
        filter(
            None,
            [
                row.death_location_street_address,
                row.death_location_city,
                row.death_location_county,
                row.death_location_state,
            ],
        )
    )

    return None if len(fields) == 0 else " ".join(fields)


def row_to_orm(row):
    data = {}
    row = row._make(map(nan_to_none, row))
    perp = row.perpetrator
    dept = row.department_present
    incident_date = parse_date(row.incident_date)
    incident_time = parse_date(row.incident_time)
    source = row.data_source_id
    use_of_force = row.death_manner
    location = orm_location(row)

    if location:
        data["location"] = location
    if incident_date or incident_time:
        t = incident_date if incident_date else incident_time
        if incident_time:
            t = t.replace(
                hour=incident_time.hour,
                minute=incident_time.minute,
                second=incident_time.second,
            )
        data["time_of_incident"] = t.isoformat()
    if perp or dept:
        data["officers"] = [
            Officer(
                first_name=dept if dept else "Unknown",
                last_name=perp if perp else "Unknown",
            )
        ]
    if row.description:
        data["description"] = row.description
    if use_of_force:
        data["use_of_force"] = [UseOfForce(item=use_of_force)]
    if source:
        data["source"] = source

    return Incident(**data)


def create_bulk(incidents, chunk_size=1000):
    with app.app_context():
        for chunk in range(0, len(incidents), chunk_size):
            db.session.add_all(incidents[chunk : chunk + chunk_size])
            db.session.flush()
        db.session.commit()


def get_rows_to_create():
    return [row_to_orm(row) for row in data.itertuples(index=False)]

# %%
orm_incidents = get_rows_to_create()

# %%
with app.app_context():
    create_bulk(orm_incidents)
    print(db.session.query(Incident).count())

# %%
origin = "http://localhost:5000"
route = lambda path: os.path.join(origin, "api/v1", path)


def authenticate():
    res = requests.post(
        route("auth/login"),
        json={"email": "test@example.com", "password": "password"},
    )
    assert res.status_code == 200
    return res.json()["access_token"]


def search(query):
    token = authenticate()
    res = requests.get(
        route("incidents/search"),
        json=query,
        headers={"Authorization": f"Bearer {token}"},
    )
    assert res.status_code == 200
    return res.json()['results']

# %%
search({"description": "shot", "location": "tx"})
# Out:
# [{'description': 'Police responded to reports of a suicidal individual who was reportedly armed. Upon arrival, police attempted to contact the individual inside. Police claim the individual eventually exited the home pointing a shotgun at officers. Police shto and killed the individual.',
#   'id': 1,
#   'location': 'McKinney Collin TX',
#   'officers': [{'first_name': 'McKinney Police Department',
#     'id': 1,
#     'incident_id': 1,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1, 'incident_id': 1, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to reports of a disturbance and a person with a weapon. Upon arrival, police spoke to the 911 caller and determined a supposedly armed individual was within the home. Police claim the individual shot at deputies from a window. Deputies returned fire, killing the person.',
#   'id': 3,
#   'location': '5300 FM 1374 Huntsville Walker TX',
#   'officers': [{'first_name': "Walker County Sheriff's Office",
#     'id': 3,
#     'incident_id': 3,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 3, 'incident_id': 3, 'item': 'Gunshot'}]},
#  {'description': 'Deputy constables were called to a home around 11 a.m. for a welfare check, possibly a CPS referral about a teen girl. As deputies tried to remove the 16-year-old girl from the home, a man inside the premises began shooting at them. The man barricaded himself inside with home with the teen and one deputy constable. Eventually, the deputy constable and the teen left the home. The man fled and carjacked a nearby driver, and a pursuit and gunfight began. The man crashed, and police shot and killed him in an exchange of gunfire.',
#   'id': 15,
#   'location': 'Jenkins Road and I-10 Winnie Chambers TX',
#   'officers': [{'first_name': "Harris County Sheriff's Office",
#     'id': 15,
#     'incident_id': 15,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 15, 'incident_id': 15, 'item': 'Gunshot'}]},
#  {'description': 'Officers pulled over a couple for speeding. During the traffic stop, the couple stated they were speeding as someone was shooting at their car and they were trying to get away. While officers were speaking to the couple, a man parked at a shell gas station and waited. He eventually approached officers and there was an exchange of words. Police allege the man eventually reached into his pants and grabbed a gun. Officers told the individual to drop it. Police claim the individual fired once, but this has not been confirmed at this time. Three officers shot and killed the man. ',
#   'id': 34,
#   'location': '9400 Bissonnet St. Houston Harris TX',
#   'officers': [{'first_name': 'Houston Police Department',
#     'id': 34,
#     'incident_id': 34,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 34, 'incident_id': 34, 'item': 'Gunshot'}]},
#  {'description': 'Police were called to a suspected carjacking. Upon arrival, they spoke to witnesses and identified an alleged suspect. The suspect allegedly ran away, and police chased after them. Police allege the person was armed and ignored several warnings to drop the weapon. Police claim the person aimed a gun at an officer, who shot and killed the person. ',
#   'id': 43,
#   'location': '3600 Race Street Fort Worth Tarrant TX',
#   'officers': [{'first_name': 'Fort Worth Police Department',
#     'id': 43,
#     'incident_id': 43,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 43, 'incident_id': 43, 'item': 'Gunshot'}]},
#  {'description': 'Deputies responded to a call about a man armed with a knife and acting erratically. He had blood on his clothing, but it was not clear where it came from. The first officer struggled with the man, and at some point, a Taser reportedly was used. When two additional officers arrived, both shot at and killed the man.',
#   'id': 57,
#   'location': '12900 Telge Road Cypress Harris TX',
#   'officers': [{'first_name': "Harris County Sheriff's Office",
#     'id': 57,
#     'incident_id': 57,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 57, 'incident_id': 57, 'item': 'Gunshot, Taser'}]},
#  {'description': "About 3:20 p.m., officers responded to a call of a person being held at gunpoint by her neighbor. Arriving officers encountered an armed man who refused to follow the officers' orders. He allegedly pointed the gun at officers, who shot and killed him.",
#   'id': 76,
#   'location': '1100 Sussex Trail Pearland Brazoria TX',
#   'officers': [{'first_name': 'Pearland Police Department',
#     'id': 76,
#     'incident_id': 76,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 76, 'incident_id': 76, 'item': 'Gunshot'}]},
#  {'description': 'Officers with the Jefferson Police Department and Seven Points Police Department requested assistance as they were following a suspect on IH 635 that was involved in an incident that had just occurred in Dallas. They shot and killed the person they were following. Details as to what precipitated the killing were withheld by police.',
#   'id': 78,
#   'location': 'La Prada Drive and I-635 Mesquite Dallas TX',
#   'officers': [{'first_name': 'Jefferson Police Department, Seven Points Police Department',
#     'id': 78,
#     'incident_id': 78,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 78, 'incident_id': 78, 'item': 'Gunshot'}]},
#  {'description': 'About 9:40 p.m., Border Patrol agents shot and killed the driver of a car that allegedly had been carrying undocumented immigrants in Laredo, Texas, after the car reversed into an agent and pinned him against another vehicle.',
#   'id': 87,
#   'location': 'Green Street and N. Smith Avenue Laredo Webb TX',
#   'officers': [{'first_name': 'U.S. Border Patrol',
#     'id': 87,
#     'incident_id': 87,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 87, 'incident_id': 87, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to reports of a suicidal individual who was reportedly armed. Upon arrival, police attempted to contact the individual inside. Police claim the individual eventually exited the home pointing a shotgun at officers. Police shto and killed the individual.',
#   'id': 101,
#   'location': 'McKinney Collin TX',
#   'officers': [{'first_name': 'McKinney Police Department',
#     'id': 101,
#     'incident_id': 101,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 101, 'incident_id': 101, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to reports of a disturbance and a person with a weapon. Upon arrival, police spoke to the 911 caller and determined a supposedly armed individual was within the home. Police claim the individual shot at deputies from a window. Deputies returned fire, killing the person.',
#   'id': 103,
#   'location': '5300 FM 1374 Huntsville Walker TX',
#   'officers': [{'first_name': "Walker County Sheriff's Office",
#     'id': 103,
#     'incident_id': 103,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 103, 'incident_id': 103, 'item': 'Gunshot'}]},
#  {'description': 'Deputy constables were called to a home around 11 a.m. for a welfare check, possibly a CPS referral about a teen girl. As deputies tried to remove the 16-year-old girl from the home, a man inside the premises began shooting at them. The man barricaded himself inside with home with the teen and one deputy constable. Eventually, the deputy constable and the teen left the home. The man fled and carjacked a nearby driver, and a pursuit and gunfight began. The man crashed, and police shot and killed him in an exchange of gunfire.',
#   'id': 115,
#   'location': 'Jenkins Road and I-10 Winnie Chambers TX',
#   'officers': [{'first_name': "Harris County Sheriff's Office",
#     'id': 115,
#     'incident_id': 115,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 115, 'incident_id': 115, 'item': 'Gunshot'}]},
#  {'description': 'Officers pulled over a couple for speeding. During the traffic stop, the couple stated they were speeding as someone was shooting at their car and they were trying to get away. While officers were speaking to the couple, a man parked at a shell gas station and waited. He eventually approached officers and there was an exchange of words. Police allege the man eventually reached into his pants and grabbed a gun. Officers told the individual to drop it. Police claim the individual fired once, but this has not been confirmed at this time. Three officers shot and killed the man. ',
#   'id': 134,
#   'location': '9400 Bissonnet St. Houston Harris TX',
#   'officers': [{'first_name': 'Houston Police Department',
#     'id': 134,
#     'incident_id': 134,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 134, 'incident_id': 134, 'item': 'Gunshot'}]},
#  {'description': 'Police were called to a suspected carjacking. Upon arrival, they spoke to witnesses and identified an alleged suspect. The suspect allegedly ran away, and police chased after them. Police allege the person was armed and ignored several warnings to drop the weapon. Police claim the person aimed a gun at an officer, who shot and killed the person. ',
#   'id': 143,
#   'location': '3600 Race Street Fort Worth Tarrant TX',
#   'officers': [{'first_name': 'Fort Worth Police Department',
#     'id': 143,
#     'incident_id': 143,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 143, 'incident_id': 143, 'item': 'Gunshot'}]},
#  {'description': 'Deputies responded to a call about a man armed with a knife and acting erratically. He had blood on his clothing, but it was not clear where it came from. The first officer struggled with the man, and at some point, a Taser reportedly was used. When two additional officers arrived, both shot at and killed the man.',
#   'id': 157,
#   'location': '12900 Telge Road Cypress Harris TX',
#   'officers': [{'first_name': "Harris County Sheriff's Office",
#     'id': 157,
#     'incident_id': 157,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 157, 'incident_id': 157, 'item': 'Gunshot, Taser'}]},
#  {'description': "About 3:20 p.m., officers responded to a call of a person being held at gunpoint by her neighbor. Arriving officers encountered an armed man who refused to follow the officers' orders. He allegedly pointed the gun at officers, who shot and killed him.",
#   'id': 176,
#   'location': '1100 Sussex Trail Pearland Brazoria TX',
#   'officers': [{'first_name': 'Pearland Police Department',
#     'id': 176,
#     'incident_id': 176,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 176, 'incident_id': 176, 'item': 'Gunshot'}]},
#  {'description': 'Officers with the Jefferson Police Department and Seven Points Police Department requested assistance as they were following a suspect on IH 635 that was involved in an incident that had just occurred in Dallas. They shot and killed the person they were following. Details as to what precipitated the killing were withheld by police.',
#   'id': 178,
#   'location': 'La Prada Drive and I-635 Mesquite Dallas TX',
#   'officers': [{'first_name': 'Jefferson Police Department, Seven Points Police Department',
#     'id': 178,
#     'incident_id': 178,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 178, 'incident_id': 178, 'item': 'Gunshot'}]},
#  {'description': 'About 9:40 p.m., Border Patrol agents shot and killed the driver of a car that allegedly had been carrying undocumented immigrants in Laredo, Texas, after the car reversed into an agent and pinned him against another vehicle.',
#   'id': 187,
#   'location': 'Green Street and N. Smith Avenue Laredo Webb TX',
#   'officers': [{'first_name': 'U.S. Border Patrol',
#     'id': 187,
#     'incident_id': 187,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 187, 'incident_id': 187, 'item': 'Gunshot'}]},
#  {'description': "During a traffic stop at about 8 p.m. on Ranch Road 674 near Brackettville, a vehicle's passenger fired at the agents, injuring one. Another Border Patrol agent shot and killed the 25-year-old man.",
#   'id': 231,
#   'location': 'Ranch Rd 674 Brackettville Kinney TX',
#   'officers': [{'first_name': 'U.S. Customs and Border Protection',
#     'id': 231,
#     'incident_id': 231,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 231, 'incident_id': 231, 'item': 'Gunshot'}]},
#  {'description': 'A shooting suspect was shot and killed after a chase when police incapacitated his vehicle with spike strips.',
#   'id': 246,
#   'location': 'US-175 Dallas Dallas TX',
#   'officers': [{'first_name': "Kaufman County Sheriff's Office",
#     'id': 246,
#     'incident_id': 246,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 246, 'incident_id': 246, 'item': 'Gunshot'}]},
#  {'description': 'U.S. Immigration and Customs Enforcement and Removal Operations agents were serving a warrant on a man around 7 a.m., when the man ran and fired at officers. Agents shot and killed him.',
#   'id': 263,
#   'location': 'Vermont St and Ferndale St San Antonio Bexar TX',
#   'officers': [{'first_name': 'U.S. Immigration and Customs Enforcement',
#     'id': 263,
#     'incident_id': 263,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 263, 'incident_id': 263, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to reports of a suicidal individual who was reportedly armed. Upon arrival, police attempted to contact the individual inside. Police claim the individual eventually exited the home pointing a shotgun at officers. Police shto and killed the individual.',
#   'id': 1101,
#   'location': 'McKinney Collin TX',
#   'officers': [{'first_name': 'McKinney Police Department',
#     'id': 319,
#     'incident_id': 1101,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 319, 'incident_id': 1101, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to reports of a suicidal individual who was reportedly armed. Upon arrival, police attempted to contact the individual inside. Police claim the individual eventually exited the home pointing a shotgun at officers. Police shto and killed the individual.',
#   'id': 1102,
#   'location': 'McKinney Collin TX',
#   'officers': [{'first_name': 'McKinney Police Department',
#     'id': 320,
#     'incident_id': 1102,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 320, 'incident_id': 1102, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to reports of a suicidal individual who was reportedly armed. Upon arrival, police attempted to contact the individual inside. Police claim the individual eventually exited the home pointing a shotgun at officers. Police shto and killed the individual.',
#   'id': 1103,
#   'location': 'McKinney Collin TX',
#   'officers': [{'first_name': 'McKinney Police Department',
#     'id': 321,
#     'incident_id': 1103,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 321, 'incident_id': 1103, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to reports of a suicidal individual who was reportedly armed. Upon arrival, police attempted to contact the individual inside. Police claim the individual eventually exited the home pointing a shotgun at officers. Police shto and killed the individual.',
#   'id': 1104,
#   'location': 'McKinney Collin TX',
#   'officers': [{'first_name': 'McKinney Police Department',
#     'id': 322,
#     'incident_id': 1104,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 322, 'incident_id': 1104, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to reports of a disturbance and a person with a weapon. Upon arrival, police spoke to the 911 caller and determined a supposedly armed individual was within the home. Police claim the individual shot at deputies from a window. Deputies returned fire, killing the person.',
#   'id': 1106,
#   'location': '5300 FM 1374 Huntsville Walker TX',
#   'officers': [{'first_name': "Walker County Sheriff's Office",
#     'id': 324,
#     'incident_id': 1106,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 324, 'incident_id': 1106, 'item': 'Gunshot'}]},
#  {'description': 'Deputy constables were called to a home around 11 a.m. for a welfare check, possibly a CPS referral about a teen girl. As deputies tried to remove the 16-year-old girl from the home, a man inside the premises began shooting at them. The man barricaded himself inside with home with the teen and one deputy constable. Eventually, the deputy constable and the teen left the home. The man fled and carjacked a nearby driver, and a pursuit and gunfight began. The man crashed, and police shot and killed him in an exchange of gunfire.',
#   'id': 1118,
#   'location': 'Jenkins Road and I-10 Winnie Chambers TX',
#   'officers': [{'first_name': "Harris County Sheriff's Office",
#     'id': 336,
#     'incident_id': 1118,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 336, 'incident_id': 1118, 'item': 'Gunshot'}]},
#  {'description': 'Officers pulled over a couple for speeding. During the traffic stop, the couple stated they were speeding as someone was shooting at their car and they were trying to get away. While officers were speaking to the couple, a man parked at a shell gas station and waited. He eventually approached officers and there was an exchange of words. Police allege the man eventually reached into his pants and grabbed a gun. Officers told the individual to drop it. Police claim the individual fired once, but this has not been confirmed at this time. Three officers shot and killed the man. ',
#   'id': 1137,
#   'location': '9400 Bissonnet St. Houston Harris TX',
#   'officers': [{'first_name': 'Houston Police Department',
#     'id': 355,
#     'incident_id': 1137,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 355, 'incident_id': 1137, 'item': 'Gunshot'}]},
#  {'description': 'Police were called to a suspected carjacking. Upon arrival, they spoke to witnesses and identified an alleged suspect. The suspect allegedly ran away, and police chased after them. Police allege the person was armed and ignored several warnings to drop the weapon. Police claim the person aimed a gun at an officer, who shot and killed the person. ',
#   'id': 1146,
#   'location': '3600 Race Street Fort Worth Tarrant TX',
#   'officers': [{'first_name': 'Fort Worth Police Department',
#     'id': 364,
#     'incident_id': 1146,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 364, 'incident_id': 1146, 'item': 'Gunshot'}]},
#  {'description': 'Deputies responded to a call about a man armed with a knife and acting erratically. He had blood on his clothing, but it was not clear where it came from. The first officer struggled with the man, and at some point, a Taser reportedly was used. When two additional officers arrived, both shot at and killed the man.',
#   'id': 1160,
#   'location': '12900 Telge Road Cypress Harris TX',
#   'officers': [{'first_name': "Harris County Sheriff's Office",
#     'id': 378,
#     'incident_id': 1160,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 378,
#     'incident_id': 1160,
#     'item': 'Gunshot, Taser'}]},
#  {'description': "About 3:20 p.m., officers responded to a call of a person being held at gunpoint by her neighbor. Arriving officers encountered an armed man who refused to follow the officers' orders. He allegedly pointed the gun at officers, who shot and killed him.",
#   'id': 1179,
#   'location': '1100 Sussex Trail Pearland Brazoria TX',
#   'officers': [{'first_name': 'Pearland Police Department',
#     'id': 397,
#     'incident_id': 1179,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 397, 'incident_id': 1179, 'item': 'Gunshot'}]},
#  {'description': 'Officers with the Jefferson Police Department and Seven Points Police Department requested assistance as they were following a suspect on IH 635 that was involved in an incident that had just occurred in Dallas. They shot and killed the person they were following. Details as to what precipitated the killing were withheld by police.',
#   'id': 1181,
#   'location': 'La Prada Drive and I-635 Mesquite Dallas TX',
#   'officers': [{'first_name': 'Jefferson Police Department, Seven Points Police Department',
#     'id': 399,
#     'incident_id': 1181,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 399, 'incident_id': 1181, 'item': 'Gunshot'}]},
#  {'description': 'About 9:40 p.m., Border Patrol agents shot and killed the driver of a car that allegedly had been carrying undocumented immigrants in Laredo, Texas, after the car reversed into an agent and pinned him against another vehicle.',
#   'id': 1190,
#   'location': 'Green Street and N. Smith Avenue Laredo Webb TX',
#   'officers': [{'first_name': 'U.S. Border Patrol',
#     'id': 408,
#     'incident_id': 1190,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 408, 'incident_id': 1190, 'item': 'Gunshot'}]},
#  {'description': "During a traffic stop at about 8 p.m. on Ranch Road 674 near Brackettville, a vehicle's passenger fired at the agents, injuring one. Another Border Patrol agent shot and killed the 25-year-old man.",
#   'id': 1234,
#   'location': 'Ranch Rd 674 Brackettville Kinney TX',
#   'officers': [{'first_name': 'U.S. Customs and Border Protection',
#     'id': 452,
#     'incident_id': 1234,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 452, 'incident_id': 1234, 'item': 'Gunshot'}]},
#  {'description': 'A shooting suspect was shot and killed after a chase when police incapacitated his vehicle with spike strips.',
#   'id': 1249,
#   'location': 'US-175 Dallas Dallas TX',
#   'officers': [{'first_name': "Kaufman County Sheriff's Office",
#     'id': 467,
#     'incident_id': 1249,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 467, 'incident_id': 1249, 'item': 'Gunshot'}]},
#  {'description': 'U.S. Immigration and Customs Enforcement and Removal Operations agents were serving a warrant on a man around 7 a.m., when the man ran and fired at officers. Agents shot and killed him.',
#   'id': 1266,
#   'location': 'Vermont St and Ferndale St San Antonio Bexar TX',
#   'officers': [{'first_name': 'U.S. Immigration and Customs Enforcement',
#     'id': 484,
#     'incident_id': 1266,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 484, 'incident_id': 1266, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to reports of a suicidal individual who was reportedly armed. Upon arrival, police attempted to contact the individual inside. Police claim the individual eventually exited the home pointing a shotgun at officers. Police shto and killed the individual.',
#   'id': 2104,
#   'location': 'McKinney Collin TX',
#   'officers': [{'first_name': 'McKinney Police Department',
#     'id': 540,
#     'incident_id': 2104,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 540, 'incident_id': 2104, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to reports of a disturbance and a person with a weapon. Upon arrival, police spoke to the 911 caller and determined a supposedly armed individual was within the home. Police claim the individual shot at deputies from a window. Deputies returned fire, killing the person.',
#   'id': 2106,
#   'location': '5300 FM 1374 Huntsville Walker TX',
#   'officers': [{'first_name': "Walker County Sheriff's Office",
#     'id': 542,
#     'incident_id': 2106,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 542, 'incident_id': 2106, 'item': 'Gunshot'}]},
#  {'description': 'Deputy constables were called to a home around 11 a.m. for a welfare check, possibly a CPS referral about a teen girl. As deputies tried to remove the 16-year-old girl from the home, a man inside the premises began shooting at them. The man barricaded himself inside with home with the teen and one deputy constable. Eventually, the deputy constable and the teen left the home. The man fled and carjacked a nearby driver, and a pursuit and gunfight began. The man crashed, and police shot and killed him in an exchange of gunfire.',
#   'id': 2118,
#   'location': 'Jenkins Road and I-10 Winnie Chambers TX',
#   'officers': [{'first_name': "Harris County Sheriff's Office",
#     'id': 554,
#     'incident_id': 2118,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 554, 'incident_id': 2118, 'item': 'Gunshot'}]},
#  {'description': 'Officers pulled over a couple for speeding. During the traffic stop, the couple stated they were speeding as someone was shooting at their car and they were trying to get away. While officers were speaking to the couple, a man parked at a shell gas station and waited. He eventually approached officers and there was an exchange of words. Police allege the man eventually reached into his pants and grabbed a gun. Officers told the individual to drop it. Police claim the individual fired once, but this has not been confirmed at this time. Three officers shot and killed the man. ',
#   'id': 2137,
#   'location': '9400 Bissonnet St. Houston Harris TX',
#   'officers': [{'first_name': 'Houston Police Department',
#     'id': 573,
#     'incident_id': 2137,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 573, 'incident_id': 2137, 'item': 'Gunshot'}]},
#  {'description': 'Police were called to a suspected carjacking. Upon arrival, they spoke to witnesses and identified an alleged suspect. The suspect allegedly ran away, and police chased after them. Police allege the person was armed and ignored several warnings to drop the weapon. Police claim the person aimed a gun at an officer, who shot and killed the person. ',
#   'id': 2146,
#   'location': '3600 Race Street Fort Worth Tarrant TX',
#   'officers': [{'first_name': 'Fort Worth Police Department',
#     'id': 582,
#     'incident_id': 2146,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 582, 'incident_id': 2146, 'item': 'Gunshot'}]},
#  {'description': 'Deputies responded to a call about a man armed with a knife and acting erratically. He had blood on his clothing, but it was not clear where it came from. The first officer struggled with the man, and at some point, a Taser reportedly was used. When two additional officers arrived, both shot at and killed the man.',
#   'id': 2160,
#   'location': '12900 Telge Road Cypress Harris TX',
#   'officers': [{'first_name': "Harris County Sheriff's Office",
#     'id': 596,
#     'incident_id': 2160,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 596,
#     'incident_id': 2160,
#     'item': 'Gunshot, Taser'}]},
#  {'description': "About 3:20 p.m., officers responded to a call of a person being held at gunpoint by her neighbor. Arriving officers encountered an armed man who refused to follow the officers' orders. He allegedly pointed the gun at officers, who shot and killed him.",
#   'id': 2179,
#   'location': '1100 Sussex Trail Pearland Brazoria TX',
#   'officers': [{'first_name': 'Pearland Police Department',
#     'id': 615,
#     'incident_id': 2179,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 615, 'incident_id': 2179, 'item': 'Gunshot'}]},
#  {'description': 'Officers with the Jefferson Police Department and Seven Points Police Department requested assistance as they were following a suspect on IH 635 that was involved in an incident that had just occurred in Dallas. They shot and killed the person they were following. Details as to what precipitated the killing were withheld by police.',
#   'id': 2181,
#   'location': 'La Prada Drive and I-635 Mesquite Dallas TX',
#   'officers': [{'first_name': 'Jefferson Police Department, Seven Points Police Department',
#     'id': 617,
#     'incident_id': 2181,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 617, 'incident_id': 2181, 'item': 'Gunshot'}]},
#  {'description': 'About 9:40 p.m., Border Patrol agents shot and killed the driver of a car that allegedly had been carrying undocumented immigrants in Laredo, Texas, after the car reversed into an agent and pinned him against another vehicle.',
#   'id': 2190,
#   'location': 'Green Street and N. Smith Avenue Laredo Webb TX',
#   'officers': [{'first_name': 'U.S. Border Patrol',
#     'id': 626,
#     'incident_id': 2190,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 626, 'incident_id': 2190, 'item': 'Gunshot'}]},
#  {'description': "During a traffic stop at about 8 p.m. on Ranch Road 674 near Brackettville, a vehicle's passenger fired at the agents, injuring one. Another Border Patrol agent shot and killed the 25-year-old man.",
#   'id': 2234,
#   'location': 'Ranch Rd 674 Brackettville Kinney TX',
#   'officers': [{'first_name': 'U.S. Customs and Border Protection',
#     'id': 670,
#     'incident_id': 2234,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 670, 'incident_id': 2234, 'item': 'Gunshot'}]},
#  {'description': 'A shooting suspect was shot and killed after a chase when police incapacitated his vehicle with spike strips.',
#   'id': 2249,
#   'location': 'US-175 Dallas Dallas TX',
#   'officers': [{'first_name': "Kaufman County Sheriff's Office",
#     'id': 685,
#     'incident_id': 2249,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 685, 'incident_id': 2249, 'item': 'Gunshot'}]},
#  {'description': 'U.S. Immigration and Customs Enforcement and Removal Operations agents were serving a warrant on a man around 7 a.m., when the man ran and fired at officers. Agents shot and killed him.',
#   'id': 2266,
#   'location': 'Vermont St and Ferndale St San Antonio Bexar TX',
#   'officers': [{'first_name': 'U.S. Immigration and Customs Enforcement',
#     'id': 702,
#     'incident_id': 2266,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 702, 'incident_id': 2266, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to reports of a suicidal individual who was reportedly armed. Upon arrival, police attempted to contact the individual inside. Police claim the individual eventually exited the home pointing a shotgun at officers. Police shto and killed the individual.',
#   'id': 4104,
#   'location': 'McKinney Collin TX',
#   'officers': [{'first_name': 'McKinney Police Department',
#     'id': 758,
#     'incident_id': 4104,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 758, 'incident_id': 4104, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to reports of a disturbance and a person with a weapon. Upon arrival, police spoke to the 911 caller and determined a supposedly armed individual was within the home. Police claim the individual shot at deputies from a window. Deputies returned fire, killing the person.',
#   'id': 4106,
#   'location': '5300 FM 1374 Huntsville Walker TX',
#   'officers': [{'first_name': "Walker County Sheriff's Office",
#     'id': 760,
#     'incident_id': 4106,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 760, 'incident_id': 4106, 'item': 'Gunshot'}]},
#  {'description': 'Deputy constables were called to a home around 11 a.m. for a welfare check, possibly a CPS referral about a teen girl. As deputies tried to remove the 16-year-old girl from the home, a man inside the premises began shooting at them. The man barricaded himself inside with home with the teen and one deputy constable. Eventually, the deputy constable and the teen left the home. The man fled and carjacked a nearby driver, and a pursuit and gunfight began. The man crashed, and police shot and killed him in an exchange of gunfire.',
#   'id': 4118,
#   'location': 'Jenkins Road and I-10 Winnie Chambers TX',
#   'officers': [{'first_name': "Harris County Sheriff's Office",
#     'id': 772,
#     'incident_id': 4118,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 772, 'incident_id': 4118, 'item': 'Gunshot'}]},
#  {'description': 'Officers pulled over a couple for speeding. During the traffic stop, the couple stated they were speeding as someone was shooting at their car and they were trying to get away. While officers were speaking to the couple, a man parked at a shell gas station and waited. He eventually approached officers and there was an exchange of words. Police allege the man eventually reached into his pants and grabbed a gun. Officers told the individual to drop it. Police claim the individual fired once, but this has not been confirmed at this time. Three officers shot and killed the man. ',
#   'id': 4137,
#   'location': '9400 Bissonnet St. Houston Harris TX',
#   'officers': [{'first_name': 'Houston Police Department',
#     'id': 791,
#     'incident_id': 4137,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 791, 'incident_id': 4137, 'item': 'Gunshot'}]},
#  {'description': 'Police were called to a suspected carjacking. Upon arrival, they spoke to witnesses and identified an alleged suspect. The suspect allegedly ran away, and police chased after them. Police allege the person was armed and ignored several warnings to drop the weapon. Police claim the person aimed a gun at an officer, who shot and killed the person. ',
#   'id': 4146,
#   'location': '3600 Race Street Fort Worth Tarrant TX',
#   'officers': [{'first_name': 'Fort Worth Police Department',
#     'id': 800,
#     'incident_id': 4146,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 800, 'incident_id': 4146, 'item': 'Gunshot'}]},
#  {'description': 'Deputies responded to a call about a man armed with a knife and acting erratically. He had blood on his clothing, but it was not clear where it came from. The first officer struggled with the man, and at some point, a Taser reportedly was used. When two additional officers arrived, both shot at and killed the man.',
#   'id': 4160,
#   'location': '12900 Telge Road Cypress Harris TX',
#   'officers': [{'first_name': "Harris County Sheriff's Office",
#     'id': 814,
#     'incident_id': 4160,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 814,
#     'incident_id': 4160,
#     'item': 'Gunshot, Taser'}]},
#  {'description': "About 3:20 p.m., officers responded to a call of a person being held at gunpoint by her neighbor. Arriving officers encountered an armed man who refused to follow the officers' orders. He allegedly pointed the gun at officers, who shot and killed him.",
#   'id': 4179,
#   'location': '1100 Sussex Trail Pearland Brazoria TX',
#   'officers': [{'first_name': 'Pearland Police Department',
#     'id': 833,
#     'incident_id': 4179,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 833, 'incident_id': 4179, 'item': 'Gunshot'}]},
#  {'description': 'Officers with the Jefferson Police Department and Seven Points Police Department requested assistance as they were following a suspect on IH 635 that was involved in an incident that had just occurred in Dallas. They shot and killed the person they were following. Details as to what precipitated the killing were withheld by police.',
#   'id': 4181,
#   'location': 'La Prada Drive and I-635 Mesquite Dallas TX',
#   'officers': [{'first_name': 'Jefferson Police Department, Seven Points Police Department',
#     'id': 835,
#     'incident_id': 4181,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 835, 'incident_id': 4181, 'item': 'Gunshot'}]},
#  {'description': 'About 9:40 p.m., Border Patrol agents shot and killed the driver of a car that allegedly had been carrying undocumented immigrants in Laredo, Texas, after the car reversed into an agent and pinned him against another vehicle.',
#   'id': 4190,
#   'location': 'Green Street and N. Smith Avenue Laredo Webb TX',
#   'officers': [{'first_name': 'U.S. Border Patrol',
#     'id': 844,
#     'incident_id': 4190,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 844, 'incident_id': 4190, 'item': 'Gunshot'}]},
#  {'description': 'A shooting suspect was shot and killed after a chase when police incapacitated his vehicle with spike strips.',
#   'id': 4249,
#   'location': 'US-175 Dallas Dallas TX',
#   'officers': [{'first_name': "Kaufman County Sheriff's Office",
#     'id': 903,
#     'incident_id': 4249,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 903, 'incident_id': 4249, 'item': 'Gunshot'}]},
#  {'description': 'U.S. Immigration and Customs Enforcement and Removal Operations agents were serving a warrant on a man around 7 a.m., when the man ran and fired at officers. Agents shot and killed him.',
#   'id': 4266,
#   'location': 'Vermont St and Ferndale St San Antonio Bexar TX',
#   'officers': [{'first_name': 'U.S. Immigration and Customs Enforcement',
#     'id': 920,
#     'incident_id': 4266,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 920, 'incident_id': 4266, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to reports of a suicidal individual who was reportedly armed. Upon arrival, police attempted to contact the individual inside. Police claim the individual eventually exited the home pointing a shotgun at officers. Police shto and killed the individual.',
#   'id': 6104,
#   'location': 'McKinney Collin TX',
#   'officers': [{'first_name': 'McKinney Police Department',
#     'id': 976,
#     'incident_id': 6104,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 976, 'incident_id': 6104, 'item': 'Gunshot'}]},
#  {'description': "During a traffic stop at about 8 p.m. on Ranch Road 674 near Brackettville, a vehicle's passenger fired at the agents, injuring one. Another Border Patrol agent shot and killed the 25-year-old man.",
#   'id': 4234,
#   'location': 'Ranch Rd 674 Brackettville Kinney TX',
#   'officers': [{'first_name': 'U.S. Customs and Border Protection',
#     'id': 888,
#     'incident_id': 4234,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 888, 'incident_id': 4234, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to reports of a disturbance and a person with a weapon. Upon arrival, police spoke to the 911 caller and determined a supposedly armed individual was within the home. Police claim the individual shot at deputies from a window. Deputies returned fire, killing the person.',
#   'id': 6106,
#   'location': '5300 FM 1374 Huntsville Walker TX',
#   'officers': [{'first_name': "Walker County Sheriff's Office",
#     'id': 978,
#     'incident_id': 6106,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 978, 'incident_id': 6106, 'item': 'Gunshot'}]},
#  {'description': 'Officers pulled over a couple for speeding. During the traffic stop, the couple stated they were speeding as someone was shooting at their car and they were trying to get away. While officers were speaking to the couple, a man parked at a shell gas station and waited. He eventually approached officers and there was an exchange of words. Police allege the man eventually reached into his pants and grabbed a gun. Officers told the individual to drop it. Police claim the individual fired once, but this has not been confirmed at this time. Three officers shot and killed the man. ',
#   'id': 6137,
#   'location': '9400 Bissonnet St. Houston Harris TX',
#   'officers': [{'first_name': 'Houston Police Department',
#     'id': 1009,
#     'incident_id': 6137,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1009, 'incident_id': 6137, 'item': 'Gunshot'}]},
#  {'description': 'Deputy constables were called to a home around 11 a.m. for a welfare check, possibly a CPS referral about a teen girl. As deputies tried to remove the 16-year-old girl from the home, a man inside the premises began shooting at them. The man barricaded himself inside with home with the teen and one deputy constable. Eventually, the deputy constable and the teen left the home. The man fled and carjacked a nearby driver, and a pursuit and gunfight began. The man crashed, and police shot and killed him in an exchange of gunfire.',
#   'id': 6118,
#   'location': 'Jenkins Road and I-10 Winnie Chambers TX',
#   'officers': [{'first_name': "Harris County Sheriff's Office",
#     'id': 990,
#     'incident_id': 6118,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 990, 'incident_id': 6118, 'item': 'Gunshot'}]},
#  {'description': 'Police were called to a suspected carjacking. Upon arrival, they spoke to witnesses and identified an alleged suspect. The suspect allegedly ran away, and police chased after them. Police allege the person was armed and ignored several warnings to drop the weapon. Police claim the person aimed a gun at an officer, who shot and killed the person. ',
#   'id': 6146,
#   'location': '3600 Race Street Fort Worth Tarrant TX',
#   'officers': [{'first_name': 'Fort Worth Police Department',
#     'id': 1018,
#     'incident_id': 6146,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1018, 'incident_id': 6146, 'item': 'Gunshot'}]},
#  {'description': "About 3:20 p.m., officers responded to a call of a person being held at gunpoint by her neighbor. Arriving officers encountered an armed man who refused to follow the officers' orders. He allegedly pointed the gun at officers, who shot and killed him.",
#   'id': 6179,
#   'location': '1100 Sussex Trail Pearland Brazoria TX',
#   'officers': [{'first_name': 'Pearland Police Department',
#     'id': 1051,
#     'incident_id': 6179,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1051, 'incident_id': 6179, 'item': 'Gunshot'}]},
#  {'description': 'Officers with the Jefferson Police Department and Seven Points Police Department requested assistance as they were following a suspect on IH 635 that was involved in an incident that had just occurred in Dallas. They shot and killed the person they were following. Details as to what precipitated the killing were withheld by police.',
#   'id': 6181,
#   'location': 'La Prada Drive and I-635 Mesquite Dallas TX',
#   'officers': [{'first_name': 'Jefferson Police Department, Seven Points Police Department',
#     'id': 1053,
#     'incident_id': 6181,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1053, 'incident_id': 6181, 'item': 'Gunshot'}]},
#  {'description': 'About 9:40 p.m., Border Patrol agents shot and killed the driver of a car that allegedly had been carrying undocumented immigrants in Laredo, Texas, after the car reversed into an agent and pinned him against another vehicle.',
#   'id': 6190,
#   'location': 'Green Street and N. Smith Avenue Laredo Webb TX',
#   'officers': [{'first_name': 'U.S. Border Patrol',
#     'id': 1062,
#     'incident_id': 6190,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1062, 'incident_id': 6190, 'item': 'Gunshot'}]},
#  {'description': 'Deputies responded to a call about a man armed with a knife and acting erratically. He had blood on his clothing, but it was not clear where it came from. The first officer struggled with the man, and at some point, a Taser reportedly was used. When two additional officers arrived, both shot at and killed the man.',
#   'id': 6160,
#   'location': '12900 Telge Road Cypress Harris TX',
#   'officers': [{'first_name': "Harris County Sheriff's Office",
#     'id': 1032,
#     'incident_id': 6160,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1032,
#     'incident_id': 6160,
#     'item': 'Gunshot, Taser'}]},
#  {'description': 'U.S. Immigration and Customs Enforcement and Removal Operations agents were serving a warrant on a man around 7 a.m., when the man ran and fired at officers. Agents shot and killed him.',
#   'id': 6266,
#   'location': 'Vermont St and Ferndale St San Antonio Bexar TX',
#   'officers': [{'first_name': 'U.S. Immigration and Customs Enforcement',
#     'id': 1138,
#     'incident_id': 6266,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1138, 'incident_id': 6266, 'item': 'Gunshot'}]},
#  {'description': "During a traffic stop at about 8 p.m. on Ranch Road 674 near Brackettville, a vehicle's passenger fired at the agents, injuring one. Another Border Patrol agent shot and killed the 25-year-old man.",
#   'id': 6234,
#   'location': 'Ranch Rd 674 Brackettville Kinney TX',
#   'officers': [{'first_name': 'U.S. Customs and Border Protection',
#     'id': 1106,
#     'incident_id': 6234,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1106, 'incident_id': 6234, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to reports of a disturbance and reportely saw Strong in the area holding a rifle at her side. Strong reportedly fired shots and fled on food. At least one officer fired at Strong, killing her.',
#   'id': 274066,
#   'location': 'Allen Collin TX',
#   'officers': [{'first_name': 'Allen Police Department',
#     'id': 1195,
#     'incident_id': 274066,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1458, 'incident_id': 274066, 'item': 'Gunshot'}]},
#  {'description': 'A shooting suspect was shot and killed after a chase when police incapacitated his vehicle with spike strips.',
#   'id': 6249,
#   'location': 'US-175 Dallas Dallas TX',
#   'officers': [{'first_name': "Kaufman County Sheriff's Office",
#     'id': 1121,
#     'incident_id': 6249,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1121, 'incident_id': 6249, 'item': 'Gunshot'}]},
#  {'description': "Police were serving a narcots arrest warrant at Ledet's apartment complex, when they claim Ledet shot at officers. The officers returned fire, killing Ledet.",
#   'id': 274077,
#   'location': 'Houston Harris TX',
#   'officers': [{'first_name': 'Houston Police Department',
#     'id': 1206,
#     'incident_id': 274077,
#     'last_name': 'William Jeffrey, Michael Vance'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1469, 'incident_id': 274077, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to a mobile home neighborhood where two individuals stated they had been robbed by an armed white male. They directed police to a mobile home where they believed the suspect was located. Police came in contact with Cravo, who they claim exited a mobile home armed with a rifle. Police allege Cravo raised the weapon, and an officer shot Cravo, killing him. ',
#   'id': 274096,
#   'location': '900 North Chestnut Street Lufkin Angelina TX',
#   'officers': [{'first_name': 'Lufkin Police Department',
#     'id': 1225,
#     'incident_id': 274096,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1488, 'incident_id': 274096, 'item': 'Gunshot'}]},
#  {'description': "Deputies were serving a felony warrant with Lufkin police officers assisting. Around 5 p.m., officers went to Bigs, formerly known as Cherry's Grocery, to arrest a customer who was wanted by the Texas Board of Pardons and Parole. When confronted, Richard Woods allegedly produced a handgun and aimed it at the deputy. The deputy then shot Woods. He allegedly reached for the handgun, which he had dropped, and the Lufkin Police officer also shot him. Whose bullet killed him was not immediately reported.",
#   'id': 274092,
#   'location': '2701 N Raguet St Lufkin Angelina TX',
#   'officers': [{'first_name': "Angelina County Sheriff's Office, Lufkin Police Department",
#     'id': 1221,
#     'incident_id': 274092,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1484, 'incident_id': 274092, 'item': 'Gunshot'}]},
#  {'description': 'Police were pursuing a sedan after it had reportedly been involved in drive-by shootings. At one point, three people exited the vehicle and reportedly ran away. Police claim one of the passengers pointed a weapon at an officer. Police shot and killed Ramirez.',
#   'id': 274110,
#   'location': '3500 Horne Street Fort Worth  Tarrant TX',
#   'officers': [{'first_name': 'Lake Worth Police Department',
#     'id': 1239,
#     'incident_id': 274110,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1502, 'incident_id': 274110, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to reports of Marry walking around a neighborhood and allegedly pointing a gun at people. Police confronted Marry, who they claim would not put the gun down. Police shot and killed Marry. ',
#   'id': 274148,
#   'location': '500 S. Bivins St. Amarillo Potter TX',
#   'officers': [{'first_name': 'Amarillo Police Department',
#     'id': 1277,
#     'incident_id': 274148,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1540, 'incident_id': 274148, 'item': 'Gunshot'}]},
#  {'description': 'Police were looking to serve felony warrants for someone else when they reportedly encountered Mireles. Police claim Mireles shot at them. Police shot and killed Mireles. ',
#   'id': 274153,
#   'location': '1223 S. Roberts St. Amarillo Potter TX',
#   'officers': [{'first_name': 'Amarillo Police Department',
#     'id': 1282,
#     'incident_id': 274153,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1545, 'incident_id': 274153, 'item': 'Gunshot'}]},
#  {'description': 'James Matalice Smith barricaded himself inside a home after shooting Deputy John Pollock. Pollock was shot while trying to serve a warrant at that home. Around 3 a.m., Smith was coming out of his home, with police believing he was surrendering. As officers attempted to take him into custody Smith fired a gun at the trooper, hitting him in the arm. Police shot and killed Smith.',
#   'id': 274158,
#   'location': 'Co Rd 230 and FM 60 Somerville Burleson TX',
#   'officers': [{'first_name': "Burleson County Sheriff's Office, Texas Department of Public Safety",
#     'id': 1287,
#     'incident_id': 274158,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1550, 'incident_id': 274158, 'item': 'Gunshot'}]},
#  {'description': "Police responded to a disturbance call on reports that a man with a gun was trying to enter someone's bedroom. Upon arrival, Officer Ian Clark shot and killed Zavaglia.",
#   'id': 274161,
#   'location': '1000 Lanark Loop Pflugerville Travis TX',
#   'officers': [{'first_name': 'Pflugerville Police Department',
#     'id': 1290,
#     'incident_id': 274161,
#     'last_name': 'Ian Clark'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1553, 'incident_id': 274161, 'item': 'Gunshot'}]},
#  {'description': 'Steven Primm allegedly threatened a group of men with a gun. When officers arrived, Primm took off on his bike and later shot an officer twice. Shortly after, a second officer fatally shot Primm.',
#   'id': 274171,
#   'location': '4900 Wycliff San Antonio Bexar TX',
#   'officers': [{'first_name': 'San Antonio Police Department',
#     'id': 1300,
#     'incident_id': 274171,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1563, 'incident_id': 274171, 'item': 'Gunshot'}]},
#  {'description': 'An individual suspected of shoplifting was shot and killed by Harris County deputies after allegedly firing at them outside of a Walmart. ',
#   'id': 274184,
#   'location': '21150 Kuykendahl Road Spring Harris TX',
#   'officers': [{'first_name': "Harris County Sheriff's Office",
#     'id': 1313,
#     'incident_id': 274184,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1576, 'incident_id': 274184, 'item': 'Gunshot'}]},
#  {'description': 'Police believe Wright shot and killed Alva Stern. Police responded to calls about the shooting, and Wright reportedly barricaded himself in an apartment. A SWAT team arrived, and Wright allegedly stepped out of the apartment and fired a gun. Nine officers shot at Wright, killing him. ',
#   'id': 274200,
#   'location': '701 Rambler Drive Waco McLennan TX',
#   'officers': [{'first_name': 'Waco Police Department',
#     'id': 1329,
#     'incident_id': 274200,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1592, 'incident_id': 274200, 'item': 'Gunshot'}]},
#  {'description': 'Police responded to the 100 block of Alabama Street and reportedly located an armed suspect. Police shot and killed Flores. There are no other details around the shooting available at this time. ',
#   'id': 274203,
#   'location': '100 Alabama Street Celina Collin TX',
#   'officers': [{'first_name': 'Celina Police Department',
#     'id': 1332,
#     'incident_id': 274203,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1595, 'incident_id': 274203, 'item': 'Gunshot'}]},
#  {'description': 'Peterson reportedly shot and killed two people in a motel and wounded two others after allegedly opening fire on police who responded to the scene. Police shot and killed Peterson.',
#   'id': 274232,
#   'location': '3421 Antoine Drive Houston Harris TX',
#   'officers': [{'first_name': 'Houston Police Department',
#     'id': 1361,
#     'incident_id': 274232,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1624, 'incident_id': 274232, 'item': 'Gunshot'}]},
#  {'description': 'Condon was reportedly shooting into a home and attempting to get in. Police responded to the scene and Condon allegedly pointed a gun at police. Police shot and killed him.',
#   'id': 274223,
#   'location': '200 Rosebud Street Boerne Kendall TX',
#   'officers': [{'first_name': 'Boerne Police Department',
#     'id': 1352,
#     'incident_id': 274223,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1615, 'incident_id': 274223, 'item': 'Gunshot'}]},
#  {'description': 'Police were investigating prostitution and attempted to pull a vehicle over. The driver of the car did not stop and led officers on a chase. The driver eventually crashed the car and reportedly refused to exit the vehicle. Police claim the driver attempted to reach at something in the vehicle, and police shot and killed the individual.',
#   'id': 274242,
#   'location': '6500 Monroe Blvd Houston Harris TX',
#   'officers': [{'first_name': 'Houston Police Department',
#     'id': 1370,
#     'incident_id': 274242,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1634, 'incident_id': 274242, 'item': 'Gunshot'}]},
#  {'description': "Police responded to reports of an assault. Police attempted to detain a man upon arrival, and a fight reportedly broke out. Police claim an individual attempted to take an officer's gun and the gun went off. A second police officer shot and killed the individual.",
#   'id': 274259,
#   'location': '7500 Park Place Blvd. Houston Harris TX',
#   'officers': [{'first_name': 'Houston Police Department',
#     'id': 1387,
#     'incident_id': 274259,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1651, 'incident_id': 274259, 'item': 'Gunshot'}]},
#  {'description': 'A trooper was reportedly getting gas at a gas station when Carranza pulled up and approached the trooper. The trooper claims Carranza grabbed the taser from his duty belt. The trooper shot and killed Carranza. ',
#   'id': 274244,
#   'location': '13000 Eastlake Blvd El Paso El Paso TX',
#   'officers': [{'first_name': 'Texas Department of Public Safety ',
#     'id': 1372,
#     'incident_id': 274244,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1636, 'incident_id': 274244, 'item': 'Gunshot'}]},
#  {'description': 'On Monday, July 5th, 2021, at approximately 11:08 a.m., a call was received at the San Antonio Police Department dispatch center for shots fired at 234 Noria. A man reportedly had two guns, was shooting, and may have shot at a reporter and cameraman. Officers arrived and found the suspected shooter a block away inside of 322 Noria. The armed man, Eduardo Mendez Amezquita, had relocated from the original shooting scene and forced his way into this occupied home, where he allegedly threatened to kill the occupants and physically assaulted one of them. Negotiators spent approximately four hours attempting to communicate with him. During this process, Amezquita threatened to burn down the home. At approximately 3 p.m., Amezquita exited the home and went into the backyard where he was seen armed with a pistol. About 3:17 p.m., five officers shot and killed him.',
#   'id': 274261,
#   'location': '322 Noria Street San Antonio Bexar TX',
#   'officers': [{'first_name': 'San Antonio Police Department',
#     'id': 1389,
#     'incident_id': 274261,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1653, 'incident_id': 274261, 'item': 'Gunshot'}]},
#  {'description': 'An officer was patrolling an apartment complex when he observed a man reportedly attempting to steal a car part. When the officer attempted to take the man into custody, a struggle ensued. During the struggle, Trevino reportedly walked up to the officer, who claims Trevino had a gun in his hand. A struggle reportedly began between the officer and Trevino. The officer shot and killed Trevino. ',
#   'id': 274279,
#   'location': '3800 Caravelle Parkway Corpus Christi Nueces TX',
#   'officers': [{'first_name': 'Corpus Christi Police Department',
#     'id': 1407,
#     'incident_id': 274279,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1671, 'incident_id': 274279, 'item': 'Gunshot'}]},
#  {'description': 'Deputies responded to a call for a welfare check. They had been informed that there was a sucidal individual armed with a gun. A deputy made contact with Winder, and shot and killed him. There are no other details available at this time.',
#   'id': 274282,
#   'location': '3640 FM2652 Graham Young TX',
#   'officers': [{'first_name': "Young County Sheriff's Office",
#     'id': 1410,
#     'incident_id': 274282,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1674, 'incident_id': 274282, 'item': 'Gunshot'}]},
#  {'description': 'Just after midnight, police were dispatched to a home on a call of a welfare check. A female caller indicated that a man was armed with a handgun, and she feared that he would harm her then himself. When officers arrived, they encountered an armed man outside the home who was pacing around a vehicle. Officers attempted to negotiate with Robert Acosta-Reyes, but he allegedly pointed the handgun at himself multiple times before pointing it at officers, who shot and killed him.',
#   'id': 274285,
#   'location': '1300 Grape Street Abilene Taylor TX',
#   'officers': [{'first_name': 'Abilene Police Department',
#     'id': 1413,
#     'incident_id': 274285,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1677, 'incident_id': 274285, 'item': 'Gunshot'}]},
#  {'description': 'Delshawn Wadlington, 30, was shot sometime before 2 p.m. Friday. Officers responding to an unrelated call heard gunshots. They investigated and found a group on Longmire Circle. Responding officers found Wadlington with a fatal gunshot wound. While officers were responding on Longmire Circle, police received several 911 calls about a man with a gun heading into Bee Creek Park. Responding officers said they saw Albert Finnie Jr. exiting a wooded area near Bee Creek.The officers allegedly saw Finnie pull out a handgun. The officers ordered Finnie to drop the weapon, but Finnie reportedly started waving the gun around, and an officer shot and killed Finnie.',
#   'id': 274289,
#   'location': '1900 Anderson St. College Station Brazos TX',
#   'officers': [{'first_name': 'College Station Police Department',
#     'id': 1417,
#     'incident_id': 274289,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1681, 'incident_id': 274289, 'item': 'Gunshot'}]},
#  {'description': "An officer attempted to pull Elmore over after he allegedly ran a stop sign. The officer ran Elmore's license and found he had an outstanding drug warrant. The officer began to arrest Elmore and claims Elmore evaded arrest and attempted to drive away. The officer attempted to drag Elmore out of the vehicle, and was reportedly afraid of being dragged by the vehicle. The officer shot Elmore multiple times, killing him. ",
#   'id': 274351,
#   'location': '9300 Charger Way Fulshear Fort Bend TX',
#   'officers': [{'first_name': 'Fulshear Police Department',
#     'id': 1479,
#     'incident_id': 274351,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1743, 'incident_id': 274351, 'item': 'Gunshot'}]},
#  {'description': 'Officers were called at about 5:12 a.m. to a report of a stabbing in the parking lot of a QuikTrip. Police said a man stabbed a woman and then fled to a creek area. Officers administered first aid to the woman, who was killed. Her identity has been withheld by police. The officers found the man, who reportedly still had a knife, in a nearby creek and told him to drop the weapon. Police said the man did not comply and attempted to harm himself with the knife. The officers used multiple bean bag rounds on the man who at one point turned toward the officer while holding the knife, police said. The officers shot and killed him.',
#   'id': 274352,
#   'location': '6000 Wichita Street Forest Hill Tarrant TX',
#   'officers': [{'first_name': 'Forest Hill Police Department',
#     'id': 1480,
#     'incident_id': 274352,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1744, 'incident_id': 274352, 'item': 'Gunshot'}]},
#  {'description': 'Diaz was reportedly pointing a gun at people in a hotel lobby. Three officers responded to the hotel, and claim Diaz pointed a gun at them. Officer Aaron Grigsby shot and killed Diaz.',
#   'id': 274358,
#   'location': '1000 Louis Henna Blvd. Round Rock Williamson TX',
#   'officers': [{'first_name': 'Round Rock Police Department',
#     'id': 1486,
#     'incident_id': 274358,
#     'last_name': 'Aaron Grigsby'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1750, 'incident_id': 274358, 'item': 'Gunshot'}]},
#  {'description': "An off-duty Fort Bend County Sheriff's Office deputy shot and killed a man who was allegedly armed with a knife outside the Knights of Columbus Hall in Needville. The incident happened around 11:45 p.m. when multiple quinceaneras and graduation parties were being held at the same location.",
#   'id': 274363,
#   'location': '13631 TX-36 Needville Fort Bend TX',
#   'officers': [{'first_name': "Fort Bend County Sheriff's Office",
#     'id': 1491,
#     'incident_id': 274363,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1755, 'incident_id': 274363, 'item': 'Gunshot'}]},
#  {'description': "Three male patrons were shot inside the CLE nightclub. One was killed. A Harris County Sheriff's deputy shot and killed the alleged shooter.",
#   'id': 274381,
#   'location': '2301 Main Street Houston Harris TX',
#   'officers': [{'first_name': "Harris County Sheriff's Office",
#     'id': 1509,
#     'incident_id': 274381,
#     'last_name': 'Unknown'}],
#   'source': 'mpv',
#   'use_of_force': [{'id': 1773, 'incident_id': 274381, 'item': 'Gunshot'}]}]
